# %% [markdown]
# # 📊 Media Campaign Performance - Exploratory Data Analysis
# **Author:** Giorgi Dzebisashvili
# **Date:** jul-2025
# **Project:** Media Spend Optimization Portfolio Project
#
# This notebook explores multi-channel digital advertising performance data. The goal is to:
# - Inspect the dataset for quality and structure
# - Compute key digital marketing metrics (CTR, ROAS, etc.)
# - Prepare clean data for further analysis and dashboarding

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Show all columns when previewing
pd.set_option('display.max_columns', None)

# Load the dataset
df = pd.read_csv('../data/media_campaign_data.csv')

# Preview first few rows
df.head()
# Out:
#        Campaign Name     Channel        Date   Spend  Clicks  Impressions  \
# 0         Search Max  Google Ads  2025-05-01  143.64     383         9771
# 1    Brand Awareness  Google Ads  2025-05-01   89.00     128         2876
# 2  Retargeting Boost  Google Ads  2025-05-01   55.15     164         3794
# 3   Engagement Surge    Meta Ads  2025-05-01   95.85     125         4041
# 4  Conversion Magnet    Meta Ads  2025-05-01  202.96     156         7221
#
#    Conversions  Revenue
# 0           53  1308.07
# 1           17   701.12
# 2           13   330.91
# 3           14   402.32
# 4           16   538.91

# %% [markdown]
# ## 📐 Basic Dataset Info
#
# Let’s check:
# - Number of rows and columns
# - Column data types
# - Non-null counts

# %%
# Shape of the dataset
print(f"Rows: {df.shape[0]}, Columns: {df.shape[1]}")

# Structure and datatypes
df.info()
# Out:
# Rows: 915, Columns: 8
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 915 entries, 0 to 914
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Campaign Name  915 non-null    object
#  1   Channel        915 non-null    object
#  2   Date           915 non-null    object
#  3   Spend          915 non-null    float64
#  4   Clicks         915 non-null    int64
#  5   Impressions    915 non-null    int64
#  6   Conversions    915 non-null    int64
#  7   Revenue        915 non-null    float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 57.3+ KB

# %% [markdown]
# ## 📊 Summary Statistics
#
# Let’s view the statistical summary of numerical columns to check ranges and distributions.
# This helps identify extreme values, zeros, or data entry errors.

# %%
df.describe()
# Out:
#             Spend      Clicks   Impressions  Conversions      Revenue
# count  915.000000  915.000000    915.000000   915.000000   915.000000
# mean   174.225574  256.300546   8709.314754    31.201093  1093.675038
# std     72.020852  168.982929   4214.439630    24.365089   930.332631
# min     51.890000   23.000000   1781.000000     1.000000    30.170000
# 25%    113.190000  130.000000   5089.000000    14.000000   423.930000
# 50%    173.160000  210.000000   8279.000000    25.000000   819.150000
# 75%    237.865000  344.000000  11511.000000    41.000000  1438.080000
# max    299.040000  905.000000  20527.000000   156.000000  5918.170000

# %% [markdown]
# ## 🧹 Missing Values Check
#
# Let’s verify that there are no missing values in critical columns like Spend, Impressions, Conversions, etc.

# %%
df.isnull().sum()
# Out:
# Campaign Name    0
# Channel          0
# Date             0
# Spend            0
# Clicks           0
# Impressions      0
# Conversions      0
# Revenue          0
# dtype: int64

# %% [markdown]
# ## 🧠 Campaign and Channel Breakdown
#
# Let’s see:
# - How many platforms are in the dataset?
# - Which campaigns exist and how often they appear?

# %%
# Unique values per channel
print("Channels:")
print(df['Channel'].value_counts(), '\n')

# Number of unique campaigns
print(f"Number of unique campaigns: {df['Campaign Name'].nunique()}")
# Out:
# Channels:
# Channel
# Google Ads    183
# Meta Ads      183
# YouTube       183
# TikTok        183
# LinkedIn      183
# Name: count, dtype: int64
#
# Number of unique campaigns: 15

# %% [markdown]
# ## 📈 Derived Metrics (CTR, CPC, CPA, ROAS)
#
# Let’s calculate key performance indicators for campaign performance:
# - **CTR (Click-Through Rate)**
# - **CPC (Cost Per Click)**
# - **CPA (Cost Per Acquisition)**
# - **ROAS (Return on Ad Spend)**
#
# We'll store these as new columns in the dataset.

# %%
# Avoid division errors by replacing 0 with NaN
df.replace(0, np.nan, inplace=True)

# Add calculated KPI columns
df['CTR'] = df['Clicks'] / df['Impressions']
df['CPC'] = df['Spend'] / df['Clicks']
df['CPA'] = df['Spend'] / df['Conversions']
df['ROAS'] = df['Revenue'] / df['Spend']

# Preview new columns
df[['CTR', 'CPC', 'CPA', 'ROAS']].describe()
# Out:
#               CTR         CPC         CPA        ROAS
# count  915.000000  915.000000  915.000000  915.000000
# mean     0.029470    0.868718    8.466572    6.338627
# std      0.011386    0.480212    6.637698    4.367615
# min      0.009861    0.286784    1.632566    0.558888
# 25%      0.019577    0.516015    4.225502    3.105384
# 50%      0.029814    0.726380    6.252903    5.397621
# 75%      0.038935    1.079767   10.349211    8.368631
# max      0.049864    2.994625   51.920000   28.612318

# %% [markdown]
# ## 🧽 Handle Invalid or Infinite Values
#
# We’ll clean up any invalid values in the calculated metrics caused by:
# - Division by 0 (e.g. no clicks or no conversions)
# - Infinite or undefined results
#
# This is a key step before moving into visualization or dashboarding.

# %%
# Replace infinite values with NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN values in key metrics
df.dropna(subset=['CTR', 'CPC', 'CPA', 'ROAS'], inplace=True)

# Check final dataset shape
print(f"Cleaned rows remaining: {df.shape[0]}")
# Out:
# Cleaned rows remaining: 915

# %% [markdown]
# ## 💾 Save Cleaned Dataset
#
# Now that we've calculated and cleaned our key KPIs, we’ll save the cleaned version of the dataset into the `data/clean/` folder for future analysis and dashboarding.

# %%
# Save to /data/clean/
df.to_csv('../data/clean/media_campaign_data_clean.csv', index=False)
print("✅ Cleaned dataset saved successfully.")
# Out:
# ✅ Cleaned dataset saved successfully.

# %% [markdown]
# ## 📊 Univariate Visualizations
#
# Let’s examine the distribution of key numeric metrics:
# - Spend
# - Impressions
# - Clicks
# - Conversions
# - Revenue
#
# This helps us spot any skew, anomalies, or outliers in the data before aggregating or modeling.

# %%
metrics = ['Spend', 'Impressions', 'Clicks', 'Conversions', 'Revenue']
plt.figure(figsize=(16, 10))

for i, metric in enumerate(metrics, 1):
    plt.subplot(2, 3, i)
    sns.histplot(df[metric], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {metric}')
    plt.xlabel(metric)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 💹 Derived Metric Distributions (CTR, CPC, CPA, ROAS)
#
# Next, we explore how our calculated KPIs are distributed to identify what's "typical" campaign performance across platforms.

# %%
kpis = ['CTR', 'CPC', 'CPA', 'ROAS']
plt.figure(figsize=(16, 8))

for i, kpi in enumerate(kpis, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[kpi], kde=True, bins=30, color='coral')
    plt.title(f'Distribution of {kpi}')
    plt.xlabel(kpi)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📈 ROAS by Channel
#
# Let’s analyze which platforms delivered the best Return on Ad Spend (ROAS). We'll use box plots to compare the distribution across channels.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Channel', y='ROAS', data=df, hue='Channel', palette='Set2', legend=False)
plt.title('ROAS Distribution by Channel')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.savefig('../images/roas_by_channel.png', dpi=300)
plt.show()

# %% [markdown]
# ## 🧭 CTR vs. ROAS
#
# This scatter plot shows if campaigns that get more clicks (higher CTR) also tend to convert better (ROAS). Helps distinguish between traffic quality vs. volume.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='CTR', y='ROAS', hue='Channel', data=df, palette='tab10')
plt.title('CTR vs ROAS by Channel')
plt.xlabel('Click-Through Rate (CTR)')
plt.ylabel('Return on Ad Spend (ROAS)')
plt.grid(True)
plt.tight_layout()
plt.savefig('../images/ctr_vs_roas.png', dpi=300)
plt.show()

# %% [markdown]
# # 📌 Business Questions & Strategic Insights
#
# Now that we’ve cleaned and explored the media campaign data, we’ll answer several business-critical questions:
#
# 1. Which channels perform best in terms of Return on Ad Spend (ROAS)?
# 2. Which campaigns are most efficient at acquiring customers (lowest CPA)?
# 3. Are high CTR campaigns also high ROAS? (i.e. does traffic quality = business value?)
# 4. How consistent is performance across channels?

# %% [markdown]
# ## 💸 Q1: Which channels had the highest average ROAS?
#
# Let’s group the data by channel and compare their average ROAS.

# %%
channel_roas = df.groupby('Channel')['ROAS'].agg(['mean', 'median', 'std', 'count']).sort_values(by='mean', ascending=False)
channel_roas.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_c12ba_row0_col0, #T_c12ba_row0_col1, #T_c12ba_row1_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c12ba_row0_col2 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_c12ba_row0_col3, #T_c12ba_row1_col3, #T_c12ba_row2_col1, #T_c12ba_row2_col3, #T_c12ba_row3_col0, #T_c12ba_row3_col2, #T_c12ba_row3_col3, #T_c12ba_row4_col0, #T_c12ba_row4_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c12ba_row1_col0 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_c12ba_row1_col1 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_c12ba_row2_col0 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_c12ba_row2_col2 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_c12ba_row3_col1 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_c12ba_row4_col1 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_c12ba_row4_col2 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# </style>
# <table id="T_c12ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c12ba_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_c12ba_level0_col1" class="col_heading level0 col1" >median</th>
#       <th id="T_c12ba_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_c12ba_level0_col3" class="col_heading level0 col3" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Channel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c12ba_level0_row0" class="row_heading level0 row0" >Meta Ads</th>
#       <td id="T_c12ba_row0_col0" class="data row0 col0" >6.946290</td>
#       <td id="T_c12ba_row0_col1" class="data row0 col1" >5.819432</td>
#       <td id="T_c12ba_row0_col2" class="data row0 col2" >4.436765</td>
#       <td id="T_c12ba_row0_col3" class="data row0 col3" >183</td>
#     </tr>
#     <tr>
#       <th id="T_c12ba_level0_row1" class="row_heading level0 row1" >TikTok</th>
#       <td id="T_c12ba_row1_col0" class="data row1 col0" >6.700776</td>
#       <td id="T_c12ba_row1_col1" class="data row1 col1" >5.530766</td>
#       <td id="T_c12ba_row1_col2" class="data row1 col2" >5.054850</td>
#       <td id="T_c12ba_row1_col3" class="data row1 col3" >183</td>
#     </tr>
#     <tr>
#       <th id="T_c12ba_level0_row2" class="row_heading level0 row2" >Google Ads</th>
#       <td id="T_c12ba_row2_col0" class="data row2 col0" >6.064800</td>
#       <td id="T_c12ba_row2_col1" class="data row2 col1" >4.895112</td>
#       <td id="T_c12ba_row2_col2" class="data row2 col2" >4.491113</td>
#       <td id="T_c12ba_row2_col3" class="data row2 col3" >183</td>
#     </tr>
#     <tr>
#       <th id="T_c12ba_level0_row3" class="row_heading level0 row3" >YouTube</th>
#       <td id="T_c12ba_row3_col0" class="data row3 col0" >5.991328</td>
#       <td id="T_c12ba_row3_col1" class="data row3 col1" >5.260637</td>
#       <td id="T_c12ba_row3_col2" class="data row3 col2" >3.716033</td>
#       <td id="T_c12ba_row3_col3" class="data row3 col3" >183</td>
#     </tr>
#     <tr>
#       <th id="T_c12ba_level0_row4" class="row_heading level0 row4" >LinkedIn</th>
#       <td id="T_c12ba_row4_col0" class="data row4 col0" >5.989943</td>
#       <td id="T_c12ba_row4_col1" class="data row4 col1" >5.052526</td>
#       <td id="T_c12ba_row4_col2" class="data row4 col2" >3.970147</td>
#       <td id="T_c12ba_row4_col3" class="data row4 col3" >183</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🎯 Q2: Which campaigns are most cost-effective (lowest CPA)?
#
# This helps prioritize which campaigns bring in the most conversions at the lowest price.

# %%
top_cpa = df.groupby('Campaign Name')['CPA'].agg(['mean', 'count']).sort_values('mean')
top_cpa.head(10).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_8b787_row0_col0, #T_8b787_row0_col1, #T_8b787_row1_col1, #T_8b787_row2_col1, #T_8b787_row3_col1, #T_8b787_row4_col1, #T_8b787_row5_col1, #T_8b787_row6_col1, #T_8b787_row7_col1, #T_8b787_row8_col1, #T_8b787_row9_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8b787_row1_col0 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_8b787_row2_col0 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_8b787_row3_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_8b787_row4_col0 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_8b787_row5_col0 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_8b787_row6_col0 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_8b787_row7_col0 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_8b787_row8_col0 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_8b787_row9_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8b787">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b787_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_8b787_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Campaign Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b787_level0_row0" class="row_heading level0 row0" >Lookalike Expansion</th>
#       <td id="T_8b787_row0_col0" class="data row0 col0" >6.879150</td>
#       <td id="T_8b787_row0_col1" class="data row0 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row1" class="row_heading level0 row1" >Creator Collab</th>
#       <td id="T_8b787_row1_col0" class="data row1 col0" >7.756755</td>
#       <td id="T_8b787_row1_col1" class="data row1 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row2" class="row_heading level0 row2" >Conversion Magnet</th>
#       <td id="T_8b787_row2_col0" class="data row2 col0" >7.790202</td>
#       <td id="T_8b787_row2_col1" class="data row2 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row3" class="row_heading level0 row3" >Video Funnel</th>
#       <td id="T_8b787_row3_col0" class="data row3 col0" >7.991087</td>
#       <td id="T_8b787_row3_col1" class="data row3 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row4" class="row_heading level0 row4" >Engagement Surge</th>
#       <td id="T_8b787_row4_col0" class="data row4 col0" >8.118850</td>
#       <td id="T_8b787_row4_col1" class="data row4 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row5" class="row_heading level0 row5" >Channel Lift</th>
#       <td id="T_8b787_row5_col0" class="data row5 col0" >8.247424</td>
#       <td id="T_8b787_row5_col1" class="data row5 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row6" class="row_heading level0 row6" >Retargeting Boost</th>
#       <td id="T_8b787_row6_col0" class="data row6 col0" >8.302686</td>
#       <td id="T_8b787_row6_col1" class="data row6 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row7" class="row_heading level0 row7" >Viral Loop</th>
#       <td id="T_8b787_row7_col0" class="data row7 col0" >8.393341</td>
#       <td id="T_8b787_row7_col1" class="data row7 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row8" class="row_heading level0 row8" >Lead Magnet</th>
#       <td id="T_8b787_row8_col0" class="data row8 col0" >8.412851</td>
#       <td id="T_8b787_row8_col1" class="data row8 col1" >61</td>
#     </tr>
#     <tr>
#       <th id="T_8b787_level0_row9" class="row_heading level0 row9" >Pre-Roll Push</th>
#       <td id="T_8b787_row9_col0" class="data row9 col0" >8.631747</td>
#       <td id="T_8b787_row9_col1" class="data row9 col1" >61</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🤔 Q3: Is high CTR associated with high ROAS?
#
# We’ll check the correlation between CTR and ROAS.

# %%
correlation = df[['CTR', 'ROAS']].corr().iloc[0, 1]
print(f"Correlation between CTR and ROAS: {correlation:.2f}")
# Out:
# Correlation between CTR and ROAS: 0.57

# %% [markdown]
# ## 📉 Q4: How consistent is performance across platforms?
#
# Standard deviation of ROAS per channel helps identify **volatile** vs **reliable** platforms.

# %%
channel_roas_std = channel_roas[['mean', 'std']].sort_values('std')
channel_roas_std.style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_e4f48_row0_col0, #T_e4f48_row0_col1, #T_e4f48_row1_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_e4f48_row1_col1 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_e4f48_row2_col0, #T_e4f48_row4_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_e4f48_row2_col1 {
#   background-color: #fd7a37;
#   color: #f1f1f1;
# }
# #T_e4f48_row3_col0 {
#   background-color: #fff4b0;
#   color: #000000;
# }
# #T_e4f48_row3_col1 {
#   background-color: #fc6430;
#   color: #f1f1f1;
# }
# #T_e4f48_row4_col0 {
#   background-color: #e41c1d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e4f48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4f48_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_e4f48_level0_col1" class="col_heading level0 col1" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Channel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4f48_level0_row0" class="row_heading level0 row0" >YouTube</th>
#       <td id="T_e4f48_row0_col0" class="data row0 col0" >5.991328</td>
#       <td id="T_e4f48_row0_col1" class="data row0 col1" >3.716033</td>
#     </tr>
#     <tr>
#       <th id="T_e4f48_level0_row1" class="row_heading level0 row1" >LinkedIn</th>
#       <td id="T_e4f48_row1_col0" class="data row1 col0" >5.989943</td>
#       <td id="T_e4f48_row1_col1" class="data row1 col1" >3.970147</td>
#     </tr>
#     <tr>
#       <th id="T_e4f48_level0_row2" class="row_heading level0 row2" >Meta Ads</th>
#       <td id="T_e4f48_row2_col0" class="data row2 col0" >6.946290</td>
#       <td id="T_e4f48_row2_col1" class="data row2 col1" >4.436765</td>
#     </tr>
#     <tr>
#       <th id="T_e4f48_level0_row3" class="row_heading level0 row3" >Google Ads</th>
#       <td id="T_e4f48_row3_col0" class="data row3 col0" >6.064800</td>
#       <td id="T_e4f48_row3_col1" class="data row3 col1" >4.491113</td>
#     </tr>
#     <tr>
#       <th id="T_e4f48_level0_row4" class="row_heading level0 row4" >TikTok</th>
#       <td id="T_e4f48_row4_col0" class="data row4 col0" >6.700776</td>
#       <td id="T_e4f48_row4_col1" class="data row4 col1" >5.054850</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # ✅ Strategic Recommendations
#
# Based on our analysis, here are key insights for media optimization:
#
# - **High ROAS Channels**: Meta Ads and TikTok delivered the highest average ROAS, indicating strong return on investment. Prioritize spend on these platforms.
# - **Cost-Efficient Campaigns**: Campaigns such as Lookalike Expansion and Creator Collab achieved the lowest average CPA, making them highly efficient at acquiring users.
# - **CTR ≠ ROI**: Click-through rate and ROAS showed only a moderate correlation. High engagement does not always translate to profitability — evaluate traffic quality alongside conversion value.
# - **Stable Performers**: YouTube and LinkedIn had the most consistent ROAS (lowest variability), making them strong candidates for predictable, steady performance.
#
# Next steps:
# - Visualize these in the dashboard
# - Share clean data with stakeholders
# - Monitor these KPIs regularly

# %% [markdown]
# # 📊 Dashboard Overview – Media Campaign Optimization
#
# To complement the analysis, an interactive dashboard was built using Looker Studio. It enables stakeholders to explore media performance data dynamically and make informed budget allocation decisions.
#
# ### 🎯 Key Features:
# - **KPI Row**: Highlights total spend, revenue, and efficiency metrics (ROAS, CPA).
# - **Channel Breakdown**: Compare performance across platforms like Meta, TikTok, YouTube, etc.
# - **Campaign-Level Insights**: Identify top-performing campaigns by ROAS or CPA.
# - **Time Series Trends**: Visualize how spend and revenue evolved over time.
# - **CTR vs ROAS Scatter Plot**: Understand relationship between engagement and profitability.
# - **Interactive Filters**: Filter by campaign, channel, and custom date ranges.
#
# ### 🧠 Business Value:
# This dashboard allows marketing teams to:
# - Monitor performance in real time
# - Prioritize campaigns based on cost-efficiency
# - Identify stable vs. volatile channels
# - Optimize spend allocation and campaign strategy
#
# 🔗 **Live Dashboard**: https://lookerstudio.google.com/reporting/eacf9e96-23e8-43bb-b2b8-7b35683f9d01
#
# 🖼️ **Screenshots available in the `images/` folder**
